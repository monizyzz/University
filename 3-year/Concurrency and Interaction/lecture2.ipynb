# %%
import pennylane as qml
import numpy as np

# %%
n_qubits = 1

dev = qml.device("default.qubit", wires=n_qubits)

# %%
n_qubits = 2

dev = qml.device("default.qubit", wires=n_qubits)

@qml.qnode(dev) # bind
def circuito():
        
    qml.Hadamard(wires=0) # 1º qubit
    qml.Hadamard(wires=1) # 2º qubit
    
    return qml.probs(wires=[0,1])

# %%
circuito()
# Out:
# array([0.25, 0.25, 0.25, 0.25])

# %%
qml.draw_mpl(circuito)()
# Out:
# (<Figure size 400x300 with 1 Axes>, <Axes: >)

# %%
n_qubits = 2

dev = qml.device("default.qubit", wires=n_qubits)

@qml.qnode(dev) # bind
def circuito():
    
    #qml.PauliX(wires=[0])
    qml.Hadamard(wires=[0])
    
    qml.CNOT(wires=[0,1])
    
    return qml.probs(wires=[0,1])

circuito()
# Out:
# array([0.5, 0. , 0. , 0.5])

# %%
qml.draw_mpl(circuito)()
# Out:
# (<Figure size 500x300 with 1 Axes>, <Axes: >)
